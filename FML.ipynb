# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohanasrivarshitha/FML-/blob/main/FML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/iris dataset/IRIS.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.shape
# Out:
# (150, 5)

# %%
import pandas as pd
df = pd.read_csv("/content/botson dataset/housing.csv")
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
import pandas as pd
from sklearn import linear_model
df =pd.read_csv("/content/botson dataset/housing.csv")
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
x = df.drop('MEDV',axis=1).values
y = df['MEDV'].values

# %%
x.shape , y.shape
# Out:
# ((489, 3), (489,))

# %%
import pandas as pd
from sklearn import linear_model
df = pd.read_csv("/content/iris dataset/IRIS.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x_rooms=x[0,1]
print(x_rooms)
# Out:
# 4.98

# %%
type(x_rooms),type(y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
x_rooms.shape,y.shape
# Out:
# ((489,), (489,))

# %%
x_rooms=x_rooms.reshape(1,-1)
y=y.reshape(1,-1)
print(x_rooms)
print(y)
# Out:
# [[4.98]]
# [[ 504000.  453600.  728700.  701400.  760200.  602700.  480900.  569100.
#    346500.  396900.  315000.  396900.  455700.  428400.  382200.  417900.
#    485100.  367500.  424200.  382200.  285600.  411600.  319200.  304500.
#    327600.  291900.  348600.  310800.  386400.  441000.  266700.  304500.
#    277200.  275100.  283500.  396900.  420000.  441000.  518700.  646800.
#    732900.  558600.  531300.  518700.  445200.  405300.  420000.  348600.
#    302400.  407400.  413700.  430500.  525000.  491400.  396900.  743400.
#    518700.  663600.  489300.  411600.  392700.  336000.  466200.  525000.
#    693000.  493500.  407400.  462000.  365400.  438900.  508200.  455700.
#    478800.  491400.  506100.  449400.  420000.  436800.  445200.  426300.
#    588000.  501900.  520800.  480900.  501900.  558600.  472500.  466200.
#    495600.  602700.  474600.  462000.  480900.  525000.  432600.  596400.
#    449400.  812700.  919800.  697200.  577500.  556500.  390600.  405300.
# ...

# %%
x_rooms.shape,y.shape
# Out:
# ((1, 1), (1, 489))

# %%
import matplotlib.pyplot as plt
plt.scatter(x_rooms,y)
plt.xlabel("no.of rooms")
plt.ylabel("values of rooms")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-8d77cf23ece4> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(x_rooms,y)
#       3 plt.xlabel("no.of rooms")
#       4 plt.ylabel("values of rooms")
#       5 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2815         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2816         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2817     __ret = gca().scatter(
#    2818         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2819         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
X_rooms=x_rooms.reshape(-2,1)
Y=y.reshape(-2,1)
print(X_rooms)
print(Y)
# Out:
# [[4.98]]
# [[ 504000.]
#  [ 453600.]
#  [ 728700.]
#  [ 701400.]
#  [ 760200.]
#  [ 602700.]
#  [ 480900.]
#  [ 569100.]
#  [ 346500.]
#  [ 396900.]
#  [ 315000.]
#  [ 396900.]
#  [ 455700.]
#  [ 428400.]
#  [ 382200.]
#  [ 417900.]
#  [ 485100.]
#  [ 367500.]
#  [ 424200.]
#  [ 382200.]
#  [ 285600.]
#  [ 411600.]
#  [ 319200.]
#  [ 304500.]
#  [ 327600.]
#  [ 291900.]
#  [ 348600.]
#  [ 310800.]
#  [ 386400.]
#  [ 441000.]
#  [ 266700.]
#  [ 304500.]
#  [ 277200.]
#  [ 275100.]
#  [ 283500.]
#  [ 396900.]
#  [ 420000.]
#  [ 441000.]
#  [ 518700.]
#  [ 646800.]
#  [ 732900.]
#  [ 558600.]
#  [ 531300.]
#  [ 518700.]
#  [ 445200.]
#  [ 405300.]
#  [ 420000.]
#  [ 348600.]
#  [ 302400.]
#  [ 407400.]
#  [ 413700.]
#  [ 430500.]
#  [ 525000.]
#  [ 491400.]
#  [ 396900.]
#  [ 743400.]
#  [ 518700.]
#  [ 663600.]
#  [ 489300.]
#  [ 411600.]
#  [ 392700.]
#  [ 336000.]
#  [ 466200.]
#  [ 525000.]
#  [ 693000.]
#  [ 493500.]
#  [ 407400.]
#  [ 462000.]
#  [ 365400.]
#  [ 438900.]
# ...

# %%
X_rooms.shape,Y.shape
# Out:
# ((1, 1), (489, 1))
